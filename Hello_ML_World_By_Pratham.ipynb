# %% [markdown]
# <a href="https://colab.research.google.com/github/nikam24/The-Hello-World-of-Deep-Learning-with-Neural-Networks/blob/main/Hello_ML_World_By_Pratham.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Importing ML supported libraries and frameworks**

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %% [markdown]
# # **Defining the Neural Network**

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %% [markdown]
# # **Loss function and Optimizer function**

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %% [markdown]
# # **Feeding Data**

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)

# %% [markdown]
# # **Training the Neural Network**

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 405ms/step - loss: 28.8130
# Epoch 2/500
# 1/1 [==============================] - 0s 10ms/step - loss: 22.6791
# Epoch 3/500
# 1/1 [==============================] - 0s 14ms/step - loss: 17.8530
# Epoch 4/500
# 1/1 [==============================] - 0s 7ms/step - loss: 14.0558
# Epoch 5/500
# 1/1 [==============================] - 0s 14ms/step - loss: 11.0682
# Epoch 6/500
# 1/1 [==============================] - 0s 7ms/step - loss: 8.7175
# Epoch 7/500
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8678
# Epoch 8/500
# 1/1 [==============================] - 0s 7ms/step - loss: 5.4125
# Epoch 9/500
# 1/1 [==============================] - 0s 7ms/step - loss: 4.2672
# Epoch 10/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.3660
# Epoch 11/500
# 1/1 [==============================] - 0s 8ms/step - loss: 2.6569
# Epoch 12/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.0987
# ...

# %% [markdown]
# # **Prdeictions on future values**

# %%
print(model.predict([10.0]))
# Out:
# 1/1 [==============================] - 0s 82ms/step
# [[31.003819]]
